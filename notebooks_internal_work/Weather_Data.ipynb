# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Import and drop utc timezone
weather = pd.read_csv("data/weather.csv")
weather.drop(columns = "timestamp_utc", inplace = True)
weather
# Out:
#                     timestamp_cet  air_temperature  water_temperature  \
# 0       2007-04-22T21:20:00+02:00             18.9               15.2
# 1       2007-04-22T21:30:00+02:00             18.1               15.2
# 2       2007-04-22T21:40:00+02:00             17.7               15.1
# 3       2007-04-22T21:50:00+02:00             17.6               15.3
# 4       2007-04-22T22:00:00+02:00             17.4               15.4
# ...                           ...              ...                ...
# 909575  2024-11-18T15:30:00+01:00             10.9               11.7
# 909576  2024-11-18T15:40:00+01:00             10.8               11.7
# 909577  2024-11-18T15:50:00+01:00             10.6               11.7
# 909578  2024-11-18T16:00:00+01:00             10.5               11.7
# 909579  2024-11-18T16:10:00+01:00             10.4               11.7
#
#         wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 0                       1.6                   0.7                   0.7
# 1                       1.3                   0.8                   0.8
# 2                       0.9                   0.2                   0.2
# 3                       0.6                   0.1                   0.1
# 4                       0.7                   0.3                   0.3
# ...                     ...                   ...                   ...
# 909575                  4.2                   1.7                   1.7
# 909576                  4.5                   1.9                   1.9
# 909577                  4.8                   1.7                   1.7
# 909578                  4.3                   1.1                   1.1
# 909579                  4.9                   0.6                   0.6
#
#         wind_direction  windchill  barometric_pressure_qfe  precipitation  \
# 0                  321       18.9                    973.5            0.0
# 1                  346       18.1                    973.7            0.0
# 2                    4       17.7                    973.7            0.0
# 3                  235       17.6                    973.8            0.0
# 4                  178       17.4                    973.9            0.0
# ...                ...        ...                      ...            ...
# 909575             213        9.4                    968.9            0.0
# 909576             281        9.2                    968.9            0.0
# 909577             272        8.9                    968.9            0.0
# 909578             274        9.4                    968.9            0.0
# 909579             156        9.1                    968.8            0.0
#
#         dew_point  global_radiation  humidity  water_level
# 0             4.4               3.0      38.0       405.94
# 1             4.8               3.0      41.0       405.94
# 2             5.1               3.0      43.0       405.94
# 3             5.7               3.0      45.0       405.94
# 4             6.3               3.0      48.0       405.94
# ...           ...               ...       ...          ...
# 909575        3.3              54.0      60.0       405.86
# 909576        3.5              43.0      61.0       405.86
# 909577        3.5              27.0      62.0       405.86
# 909578        3.5              31.0      62.0       405.86
# 909579        3.4              28.0      62.0       405.86
#
# [909580 rows x 14 columns]

# %%
#Transform to datetime format
pd.to_datetime(weather["timestamp_cet"])
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_28304\2309803379.py:2: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   pd.to_datetime(weather["timestamp_cet"])
# 0         2007-04-22 21:20:00+02:00
# 1         2007-04-22 21:30:00+02:00
# 2         2007-04-22 21:40:00+02:00
# 3         2007-04-22 21:50:00+02:00
# 4         2007-04-22 22:00:00+02:00
#                     ...
# 909575    2024-11-18 15:30:00+01:00
# 909576    2024-11-18 15:40:00+01:00
# 909577    2024-11-18 15:50:00+01:00
# 909578    2024-11-18 16:00:00+01:00
# 909579    2024-11-18 16:10:00+01:00
# Name: timestamp_cet, Length: 909580, dtype: object

# %%
#Filter for only 2024 Data and see if there are missing values
weather_filtered = weather.loc[weather["timestamp_cet"] >= "2024-01-01 00:00"]
weather_filtered.isna().sum()
# Out:
# timestamp_cet              0
# air_temperature            0
# water_temperature          0
# wind_gust_max_10min        0
# wind_speed_avg_10min       0
# wind_force_avg_10min       0
# wind_direction             0
# windchill                  0
# barometric_pressure_qfe    0
# precipitation              0
# dew_point                  0
# global_radiation           0
# humidity                   0
# water_level                0
# dtype: int64

# %% [markdown]
# ### Deal with time change VBZ

# %%
#Import hardbruecke data to copy date
df = pd.read_csv("data/frequenzen_hardbruecke_2024.csv")
# Transform the smaller dataset to wide format
df_wide = df.pivot_table(
    index="Timestamp", columns= "Name", values=["In", "Out"]).reset_index()
# Display the wide data
df_wide
#We just need TimeStamp and In and Outflow for the Ost-VBZ Total and West-WBZ Total
#Selecting columns that we need 
relevant_columns = [('Timestamp', ''), ('In', 'Ost-VBZ Total'), ('In', 'West-VBZ total')]
df_VBZ = df_wide[relevant_columns]

#Filter for only 2024 Data
df_VBZ[df_VBZ["Timestamp"] >= '2024-01-01 00:00:00']

#Doppel index wegmachen
df_VBZ = df_VBZ.droplevel(level=0, axis=1)
df_VBZ.rename(columns = {'':'Timestamp'}, inplace = True)


# Ensure the Timestamp column is a datetime object
df_VBZ['Timestamp'] = pd.to_datetime(df_VBZ['Timestamp'])
df_VBZ
# Out:
# Name            Timestamp  Ost-VBZ Total  West-VBZ total
# 0     2024-01-16 14:55:00           13.0            20.0
# 1     2024-01-16 15:00:00           14.0            11.0
# 2     2024-01-16 15:05:00           29.0             6.0
# 3     2024-01-16 15:10:00           18.0             9.0
# 4     2024-01-16 15:15:00           33.0            16.0
# ...                   ...            ...             ...
# 82616 2024-11-12 08:35:00           62.0             6.0
# 82617 2024-11-12 08:40:00           76.0            36.0
# 82618 2024-11-12 08:45:00           70.0            31.0
# 82619 2024-11-12 08:50:00           35.0            11.0
# 82620 2024-11-12 08:55:00           68.0            33.0
#
# [82621 rows x 3 columns]

# %%
#deal with time change vbz
#shift whole summer time one hour back to get winter time, do this until 27.10.2024 01:55, afterwards you will get a missing hour in october which I suppose they dropped
#because they had data two times, we get this missing data back by interpolation

df_VBZ[df_VBZ["Timestamp"] >= '2024-10-27 01:50:00']
df_VBZ[df_VBZ["Timestamp"] >= '2024-03-31 01:50:00']
# Out:
# Name            Timestamp  Ost-VBZ Total  West-VBZ total
# 20165 2024-03-31 01:50:00            0.0             7.0
# 20166 2024-03-31 01:55:00            0.0             NaN
# 20167 2024-03-31 03:00:00            2.0             2.0
# 20168 2024-03-31 03:05:00            NaN             0.0
# 20169 2024-03-31 03:10:00            NaN             NaN
# ...                   ...            ...             ...
# 82616 2024-11-12 08:35:00           62.0             6.0
# 82617 2024-11-12 08:40:00           76.0            36.0
# 82618 2024-11-12 08:45:00           70.0            31.0
# 82619 2024-11-12 08:50:00           35.0            11.0
# 82620 2024-11-12 08:55:00           68.0            33.0
#
# [62456 rows x 3 columns]

# %%
#Execute the above thought
df_VBZ.loc[
    (df_VBZ["Timestamp"] > '2024-03-31 01:55:00') & 
    (df_VBZ["Timestamp"] < '2024-10-27 02:00:00'), 
    "Timestamp"
] -= pd.Timedelta(hours=1)

# %%
#Check if it shifted correctly (it did)
df_VBZ[78160:]
df_VBZ[20165:]
# Out:
# Name            Timestamp  Ost-VBZ Total  West-VBZ total
# 20165 2024-03-31 01:50:00            0.0             7.0
# 20166 2024-03-31 01:55:00            0.0             NaN
# 20167 2024-03-31 02:00:00            2.0             2.0
# 20168 2024-03-31 02:05:00            NaN             0.0
# 20169 2024-03-31 02:10:00            NaN             NaN
# ...                   ...            ...             ...
# 82616 2024-11-12 08:35:00           62.0             6.0
# 82617 2024-11-12 08:40:00           76.0            36.0
# 82618 2024-11-12 08:45:00           70.0            31.0
# 82619 2024-11-12 08:50:00           35.0            11.0
# 82620 2024-11-12 08:55:00           68.0            33.0
#
# [62456 rows x 3 columns]

# %% [markdown]
# ### Deal With Missing Values In Hardbruecke

# %%
# Generate a full range of timestamps from the first to the last timestamp, at 5-minute intervals
full_range = pd.date_range(start=df_VBZ['Timestamp'].min(), end=df_VBZ['Timestamp'].max(), freq='5T')

# Find the missing timestamps by comparing with the existing ones
missing_timestamps = full_range[~full_range.isin(df_VBZ['Timestamp'])]

# Print the missing timestamps
print(missing_timestamps[1099])
missing_timestamps = pd.DataFrame(missing_timestamps)
missing_timestamps.rename(columns = {0: 'Timestamp'}, inplace = True)
missing_timestamps
missing_timestamps
# Out:
# 2024-03-18 04:55:00
# C:\Users\micha\AppData\Local\Temp\ipykernel_28304\3856086806.py:2: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   full_range = pd.date_range(start=df_VBZ['Timestamp'].min(), end=df_VBZ['Timestamp'].max(), freq='5T')
#                Timestamp
# 0    2024-01-17 00:45:00
# 1    2024-01-17 01:00:00
# 2    2024-01-17 01:05:00
# 3    2024-01-17 01:20:00
# 4    2024-01-17 01:25:00
# ...                  ...
# 3991 2024-11-12 03:40:00
# 3992 2024-11-12 03:50:00
# 3993 2024-11-12 03:55:00
# 3994 2024-11-12 04:30:00
# 3995 2024-11-12 04:40:00
#
# [3996 rows x 1 columns]

# %%
# Duplicate rows
healed_VBZ = pd.concat([df_VBZ, missing_timestamps], ignore_index=True)

healed_VBZ

# Sort by timestamp to maintain order
healed_VBZ = healed_VBZ.sort_values(by='Timestamp').reset_index(drop=True)


healed_VBZ
# Out:
#                 Timestamp  Ost-VBZ Total  West-VBZ total
# 0     2024-01-16 14:55:00           13.0            20.0
# 1     2024-01-16 15:00:00           14.0            11.0
# 2     2024-01-16 15:05:00           29.0             6.0
# 3     2024-01-16 15:10:00           18.0             9.0
# 4     2024-01-16 15:15:00           33.0            16.0
# ...                   ...            ...             ...
# 86612 2024-11-12 08:35:00           62.0             6.0
# 86613 2024-11-12 08:40:00           76.0            36.0
# 86614 2024-11-12 08:45:00           70.0            31.0
# 86615 2024-11-12 08:50:00           35.0            11.0
# 86616 2024-11-12 08:55:00           68.0            33.0
#
# [86617 rows x 3 columns]

# %%
#Observe where missing values are located
healed_VBZ_mv = healed_VBZ.copy() #create a copy to work on
healed_VBZ_mv.fillna(-100, inplace = True)
print(healed_VBZ_mv.isna().sum())

fig, axs = plt.subplots(2,1, figsize = (20, 12))
axs[0].plot(healed_VBZ_mv["Timestamp"].tail(8000), healed_VBZ_mv["Ost-VBZ Total"].tail(8000))
axs[1].plot(healed_VBZ_mv["Timestamp"].tail(8000), healed_VBZ_mv["West-VBZ total"].tail(8000))
# Out:
# Timestamp         0
# Ost-VBZ Total     0
# West-VBZ total    0
# dtype: int64

# %%
Ost_VBZ_Total_ff = healed_VBZ['Ost-VBZ Total'].ffill()
Ost_VBZ_Total_bf = healed_VBZ['Ost-VBZ Total'].bfill()

West_VBZ_total_ff = healed_VBZ['West-VBZ total'].ffill()
West_VBZ_total_bf = healed_VBZ['West-VBZ total'].bfill()

healed_VBZ['Ost-VBZ Total'] = healed_VBZ['Ost-VBZ Total'].fillna((Ost_VBZ_Total_ff + Ost_VBZ_Total_bf) / 2)
healed_VBZ['West-VBZ total'] = healed_VBZ['West-VBZ total'].fillna((West_VBZ_total_ff + West_VBZ_total_bf) / 2)
#plot to see results
fig, axs = plt.subplots(2,1, figsize = (20, 12))
axs[0].plot(healed_VBZ["Timestamp"].tail(8000), healed_VBZ["Ost-VBZ Total"].tail(8000))
axs[1].plot(healed_VBZ["Timestamp"].tail(8000), healed_VBZ["West-VBZ total"].tail(8000))

# %% [markdown]
# ### Workday data

# %%
# Duplicate rows
duplicated_weather = pd.concat([weather_filtered, weather_filtered])

# Sort by timestamp to maintain order
duplicated_weather = duplicated_weather.sort_values(by='timestamp_cet').reset_index(drop=True)

# Convert 'timestamp_cet' to datetime format
duplicated_weather['timestamp_cet'] = pd.to_datetime(duplicated_weather['timestamp_cet'])

# Add 5 minutes to every second row's timestamp
duplicated_weather.loc[1::2, 'timestamp_cet'] += pd.Timedelta(minutes=5)



five_weather = duplicated_weather


# Locate all observations after 16 january to match hardbrücke
five_weather = five_weather.loc[five_weather["timestamp_cet"] > pd.Timestamp("2024-01-16 14:50+01:00")]
five_weather = five_weather.reset_index()
five_weather = five_weather[0:85865]

#change timestamp_cet to Timestamp
five_weather.rename(columns = {'timestamp_cet': 'Timestamp'}, inplace = True)
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_28304\1333939375.py:8: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   duplicated_weather['timestamp_cet'] = pd.to_datetime(duplicated_weather['timestamp_cet'])

# %%
#Change time away from utc to normal time for five_weather
five_weather['Timestamp'] = pd.to_datetime(five_weather['Timestamp'], utc = True)
five_weather = five_weather.copy()
five_weather['Timestamp'] = five_weather['Timestamp'] + pd.Timedelta(hours=1)
five_weather['Timestamp'] = five_weather['Timestamp'].dt.tz_localize(None)
five_weather
# Out:
#        index           Timestamp  air_temperature  water_temperature  \
# 0       4145 2024-01-16 14:55:00              4.0                5.4
# 1       4146 2024-01-16 15:00:00              3.9                5.5
# 2       4147 2024-01-16 15:05:00              3.9                5.5
# 3       4148 2024-01-16 15:10:00              3.8                5.5
# 4       4149 2024-01-16 15:15:00              3.8                5.5
# ...      ...                 ...              ...                ...
# 85860  90005 2024-11-12 08:35:00              6.1               13.0
# 85861  90006 2024-11-12 08:40:00              6.1               13.0
# 85862  90007 2024-11-12 08:45:00              6.1               13.0
# 85863  90008 2024-11-12 08:50:00              6.1               13.0
# 85864  90009 2024-11-12 08:55:00              6.1               13.0
#
#        wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 0                      4.1                   1.9                   1.9
# 1                      2.9                   1.6                   1.6
# 2                      2.9                   1.6                   1.6
# 3                      2.8                   0.9                   0.9
# 4                      2.8                   0.9                   0.9
# ...                    ...                   ...                   ...
# 85860                  4.8                   3.2                   3.2
# 85861                  5.1                   3.4                   3.4
# 85862                  5.1                   3.4                   3.4
# 85863                  5.8                   3.8                   3.8
# 85864                  5.8                   3.8                   3.8
#
#        wind_direction  windchill  barometric_pressure_qfe  precipitation  \
# 0                  44        1.9                    962.5            0.0
# 1                   3        3.0                    962.5            0.0
# 2                   3        3.0                    962.5            0.0
# 3                  55        3.5                    962.4            0.0
# 4                  55        3.5                    962.4            0.0
# ...               ...        ...                      ...            ...
# 85860              39        2.6                    977.7            0.0
# 85861              37        2.6                    977.8            0.0
# 85862              37        2.6                    977.8            0.0
# 85863              45        2.3                    977.8            0.0
# 85864              45        2.3                    977.8            0.0
#
#        dew_point  global_radiation  humidity  water_level
# 0           -2.4             184.0      63.0       405.79
# 1           -2.5             137.0      63.0       405.79
# 2           -2.5             137.0      63.0       405.79
# 3           -2.6             169.0      63.0       405.79
# 4           -2.6             169.0      63.0       405.79
# ...          ...               ...       ...          ...
# 85860        4.9              13.0      92.0       405.87
# 85861        5.0              20.0      92.0       405.86
# 85862        5.0              20.0      92.0       405.86
# 85863        5.0              29.0      92.0       405.87
# 85864        5.0              29.0      92.0       405.87
#
# [85865 rows x 15 columns]

# %%
feiertage = pd.DataFrame({
	"Datum": ["2024-01-01", "2024-01-02", "2024-03-28", "2024-03-29", "2024-04-01", "2024-04-15", "2024-05-01", "2024-05-08", "2024-05-09", "2024-05-10", "2024-05-20", "2024-08-01", "2024-09-09", "2024-12-24", "2024-12-25", "2024-12-26", "2024-12-27", "2024-12-30", "2024-12-31"]
})
feiertage["Datum"] = pd.to_datetime(feiertage["Datum"])
#Add index if holiday or not
feiertage["Feiertag"] = 1
feiertage
# Out:
#         Datum  Feiertag
# 0  2024-01-01         1
# 1  2024-01-02         1
# 2  2024-03-28         1
# 3  2024-03-29         1
# 4  2024-04-01         1
# 5  2024-04-15         1
# 6  2024-05-01         1
# 7  2024-05-08         1
# 8  2024-05-09         1
# 9  2024-05-10         1
# 10 2024-05-20         1
# 11 2024-08-01         1
# 12 2024-09-09         1
# 13 2024-12-24         1
# 14 2024-12-25         1
# 15 2024-12-26         1
# 16 2024-12-27         1
# 17 2024-12-30         1
# 18 2024-12-31         1

# %%
# Erstelle eine Datumsreihe für das Jahr 2024
dates = pd.date_range(start="2024-01-01", end="2024-12-31", freq="D")

# Erstelle einen DataFrame mit Wochentagen
calendar = pd.DataFrame({
    "Datum": dates,
    "Wochentag": dates.day_name()  # Gibt den Wochentag als Namen aus
})

calendar["Datum"] = pd.to_datetime(calendar["Datum"])
pd.DataFrame(calendar)
calendar["Feiertag"] = 0
calendar
# Out:
#          Datum  Wochentag  Feiertag
# 0   2024-01-01     Monday         0
# 1   2024-01-02    Tuesday         0
# 2   2024-01-03  Wednesday         0
# 3   2024-01-04   Thursday         0
# 4   2024-01-05     Friday         0
# ..         ...        ...       ...
# 361 2024-12-27     Friday         0
# 362 2024-12-28   Saturday         0
# 363 2024-12-29     Sunday         0
# 364 2024-12-30     Monday         0
# 365 2024-12-31    Tuesday         0
#
# [366 rows x 3 columns]

# %%
# Put the data together
calendar2 = np.where(calendar["Datum"].isin(feiertage["Datum"]), 1, 0)
calendar["Feiertag"] = calendar2

# %%
# Put the data together
calendar.loc[calendar["Wochentag"].isin(["Saturday", "Sunday"]), "Feiertag"] = 1

# %%
calendar
# Out:
#          Datum  Wochentag  Feiertag
# 0   2024-01-01     Monday         1
# 1   2024-01-02    Tuesday         1
# 2   2024-01-03  Wednesday         0
# 3   2024-01-04   Thursday         0
# 4   2024-01-05     Friday         0
# ..         ...        ...       ...
# 361 2024-12-27     Friday         1
# 362 2024-12-28   Saturday         1
# 363 2024-12-29     Sunday         1
# 364 2024-12-30     Monday         1
# 365 2024-12-31    Tuesday         1
#
# [366 rows x 3 columns]

# %%
#Data Frame with only holiday variable
Feiertag_df = calendar[["Datum", "Feiertag"]]
Feiertag_df["Datum"] = pd.to_datetime(Feiertag_df["Datum"])
Feiertag_df.rename(columns={"Datum": "Date"}, inplace=True)

Feiertag_df
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_28304\4242840774.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Feiertag_df["Datum"] = pd.to_datetime(Feiertag_df["Datum"])
# C:\Users\micha\AppData\Local\Temp\ipykernel_28304\4242840774.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Feiertag_df.rename(columns={"Datum": "Date"}, inplace=True)
#           Date  Feiertag
# 0   2024-01-01         1
# 1   2024-01-02         1
# 2   2024-01-03         0
# 3   2024-01-04         0
# 4   2024-01-05         0
# ..         ...       ...
# 361 2024-12-27         1
# 362 2024-12-28         1
# 363 2024-12-29         1
# 364 2024-12-30         1
# 365 2024-12-31         1
#
# [366 rows x 2 columns]

# %%
##Put feiertag and weather data together

copy_weather = five_weather.copy()
# Create a temporary "Date" column by extracting the date from the timestamp
copy_weather["Date"] = pd.to_datetime(copy_weather["Timestamp"]).dt.date

copy_weather

# Convert the 'Date' column in both dataframes to datetime64[ns]
copy_weather['Date'] = pd.to_datetime(copy_weather['Date'])
Feiertag_df['Date'] = pd.to_datetime(Feiertag_df['Date'])

# Merge the DataFrames on the date
merged_df = pd.merge(
    copy_weather, 
    Feiertag_df, 
    on= "Date",  # Replace "Datum" with the correct column name in Feiertag_df
    how="left"  # Adjust "how" based on your merge requirement
)


five_weather = merged_df.copy()

# Drop the temporary "Date" column if no longer needed
five_weather.drop(columns=["Date"], inplace=True)
five_weather
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_28304\2689946342.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Feiertag_df['Date'] = pd.to_datetime(Feiertag_df['Date'])
#        index           Timestamp  air_temperature  water_temperature  \
# 0       4145 2024-01-16 14:55:00              4.0                5.4
# 1       4146 2024-01-16 15:00:00              3.9                5.5
# 2       4147 2024-01-16 15:05:00              3.9                5.5
# 3       4148 2024-01-16 15:10:00              3.8                5.5
# 4       4149 2024-01-16 15:15:00              3.8                5.5
# ...      ...                 ...              ...                ...
# 85860  90005 2024-11-12 08:35:00              6.1               13.0
# 85861  90006 2024-11-12 08:40:00              6.1               13.0
# 85862  90007 2024-11-12 08:45:00              6.1               13.0
# 85863  90008 2024-11-12 08:50:00              6.1               13.0
# 85864  90009 2024-11-12 08:55:00              6.1               13.0
#
#        wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 0                      4.1                   1.9                   1.9
# 1                      2.9                   1.6                   1.6
# 2                      2.9                   1.6                   1.6
# 3                      2.8                   0.9                   0.9
# 4                      2.8                   0.9                   0.9
# ...                    ...                   ...                   ...
# 85860                  4.8                   3.2                   3.2
# 85861                  5.1                   3.4                   3.4
# 85862                  5.1                   3.4                   3.4
# 85863                  5.8                   3.8                   3.8
# 85864                  5.8                   3.8                   3.8
#
#        wind_direction  windchill  barometric_pressure_qfe  precipitation  \
# 0                  44        1.9                    962.5            0.0
# 1                   3        3.0                    962.5            0.0
# 2                   3        3.0                    962.5            0.0
# 3                  55        3.5                    962.4            0.0
# 4                  55        3.5                    962.4            0.0
# ...               ...        ...                      ...            ...
# 85860              39        2.6                    977.7            0.0
# 85861              37        2.6                    977.8            0.0
# 85862              37        2.6                    977.8            0.0
# 85863              45        2.3                    977.8            0.0
# 85864              45        2.3                    977.8            0.0
#
#        dew_point  global_radiation  humidity  water_level  Feiertag
# 0           -2.4             184.0      63.0       405.79         0
# 1           -2.5             137.0      63.0       405.79         0
# 2           -2.5             137.0      63.0       405.79         0
# 3           -2.6             169.0      63.0       405.79         0
# 4           -2.6             169.0      63.0       405.79         0
# ...          ...               ...       ...          ...       ...
# 85860        4.9              13.0      92.0       405.87         0
# 85861        5.0              20.0      92.0       405.86         0
# 85862        5.0              20.0      92.0       405.86         0
# 85863        5.0              29.0      92.0       405.87         0
# 85864        5.0              29.0      92.0       405.87         0
#
# [85865 rows x 16 columns]

# %% [markdown]
# ### Deal With Missing Values In Hardbruecke

# %% [markdown]
# ### Deal with time change weather

# %%
#To see why i did this you have to take out transformation of weather away from timezone sensitive above and insert it below the data frame (dont forget to reverse this...)
#Deal with time change (summer time happens between observations 21380 and 21381)
# (winter time happens between 81182 and 81183) (look below for further analysis)
five_weather.loc[21379:]
five_weather.loc[81180:]
# Out:
#        index           Timestamp  air_temperature  water_temperature  \
# 81180  85325 2024-10-27 00:45:00             11.7               15.1
# 81181  85326 2024-10-27 00:50:00             11.6               15.1
# 81182  85327 2024-10-27 00:55:00             11.6               15.1
# 81183  85328 2024-10-27 02:00:00             11.6               15.1
# 81184  85329 2024-10-27 02:05:00             11.6               15.1
# ...      ...                 ...              ...                ...
# 85860  90005 2024-11-12 08:35:00              6.1               13.0
# 85861  90006 2024-11-12 08:40:00              6.1               13.0
# 85862  90007 2024-11-12 08:45:00              6.1               13.0
# 85863  90008 2024-11-12 08:50:00              6.1               13.0
# 85864  90009 2024-11-12 08:55:00              6.1               13.0
#
#        wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 81180                  2.9                   1.6                   1.6
# 81181                  1.7                   0.9                   0.9
# 81182                  1.7                   0.9                   0.9
# 81183                  2.8                   1.3                   1.3
# 81184                  2.8                   1.3                   1.3
# ...                    ...                   ...                   ...
# 85860                  4.8                   3.2                   3.2
# 85861                  5.1                   3.4                   3.4
# 85862                  5.1                   3.4                   3.4
# 85863                  5.8                   3.8                   3.8
# 85864                  5.8                   3.8                   3.8
#
#        wind_direction  windchill  barometric_pressure_qfe  precipitation  \
# 81180             142       11.5                    971.0            0.0
# 81181              61       11.6                    971.0            0.0
# 81182              61       11.6                    971.0            0.0
# 81183             149       11.6                    971.2            0.0
# 81184             149       11.6                    971.2            0.0
# ...               ...        ...                      ...            ...
# 85860              39        2.6                    977.7            0.0
# 85861              37        2.6                    977.8            0.0
# 85862              37        2.6                    977.8            0.0
# 85863              45        2.3                    977.8            0.0
# 85864              45        2.3                    977.8            0.0
#
#        dew_point  global_radiation  humidity  water_level  Feiertag
# 81180       10.6               0.0      93.0       405.97         1
# 81181       10.6               0.0      94.0       405.97         1
# 81182       10.6               0.0      94.0       405.97         1
# 81183       10.6               0.0      94.0       405.97         1
# 81184       10.6               0.0      94.0       405.97         1
# ...          ...               ...       ...          ...       ...
# 85860        4.9              13.0      92.0       405.87         0
# 85861        5.0              20.0      92.0       405.86         0
# 85862        5.0              20.0      92.0       405.86         0
# 85863        5.0              29.0      92.0       405.87         0
# 85864        5.0              29.0      92.0       405.87         0
#
# [4685 rows x 16 columns]

# %%
#Change time away from utc to normal time
#five_weather['Timestamp'] = pd.to_datetime(five_weather['Timestamp'], utc = True)
#five_weather = five_weather.copy()
#five_weather['Timestamp'] = five_weather['Timestamp'] + pd.Timedelta(hours=1)
#five_weather['Timestamp'] = five_weather['Timestamp'].dt.tz_localize(None)
#five_weather

# %%
#So if we  compare the time change before utc was changed to normal time and after, we see that the code already transforms our variables from summer time to winter time 
#at the 31st of march so I dont have to do anything there, lets see also for the 27th of october
#31st of march
five_weather[five_weather["Timestamp"] == "2024-03-31 01:55:00"]
five_weather[21379:]

#27th of october so I see that all observations until 81183 are in winter time still and got correctly recognized, the ones after have falsely been assumed to have been in summer time
#and have thus to be shifted by one hour backwards
five_weather[81180:]
# Out:
#        index           Timestamp  air_temperature  water_temperature  \
# 81180  85325 2024-10-27 00:45:00             11.7               15.1
# 81181  85326 2024-10-27 00:50:00             11.6               15.1
# 81182  85327 2024-10-27 00:55:00             11.6               15.1
# 81183  85328 2024-10-27 02:00:00             11.6               15.1
# 81184  85329 2024-10-27 02:05:00             11.6               15.1
# ...      ...                 ...              ...                ...
# 85860  90005 2024-11-12 08:35:00              6.1               13.0
# 85861  90006 2024-11-12 08:40:00              6.1               13.0
# 85862  90007 2024-11-12 08:45:00              6.1               13.0
# 85863  90008 2024-11-12 08:50:00              6.1               13.0
# 85864  90009 2024-11-12 08:55:00              6.1               13.0
#
#        wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 81180                  2.9                   1.6                   1.6
# 81181                  1.7                   0.9                   0.9
# 81182                  1.7                   0.9                   0.9
# 81183                  2.8                   1.3                   1.3
# 81184                  2.8                   1.3                   1.3
# ...                    ...                   ...                   ...
# 85860                  4.8                   3.2                   3.2
# 85861                  5.1                   3.4                   3.4
# 85862                  5.1                   3.4                   3.4
# 85863                  5.8                   3.8                   3.8
# 85864                  5.8                   3.8                   3.8
#
#        wind_direction  windchill  barometric_pressure_qfe  precipitation  \
# 81180             142       11.5                    971.0            0.0
# 81181              61       11.6                    971.0            0.0
# 81182              61       11.6                    971.0            0.0
# 81183             149       11.6                    971.2            0.0
# 81184             149       11.6                    971.2            0.0
# ...               ...        ...                      ...            ...
# 85860              39        2.6                    977.7            0.0
# 85861              37        2.6                    977.8            0.0
# 85862              37        2.6                    977.8            0.0
# 85863              45        2.3                    977.8            0.0
# 85864              45        2.3                    977.8            0.0
#
#        dew_point  global_radiation  humidity  water_level  Feiertag
# 81180       10.6               0.0      93.0       405.97         1
# 81181       10.6               0.0      94.0       405.97         1
# 81182       10.6               0.0      94.0       405.97         1
# 81183       10.6               0.0      94.0       405.97         1
# 81184       10.6               0.0      94.0       405.97         1
# ...          ...               ...       ...          ...       ...
# 85860        4.9              13.0      92.0       405.87         0
# 85861        5.0              20.0      92.0       405.86         0
# 85862        5.0              20.0      92.0       405.86         0
# 85863        5.0              29.0      92.0       405.87         0
# 85864        5.0              29.0      92.0       405.87         0
#
# [4685 rows x 16 columns]

# %%
#shift from observation 81183 onwards one hour backwards
five_weather.loc[81183:, 'Timestamp'] = five_weather.loc[81183:, 'Timestamp'] - pd.Timedelta(hours=1)
five_weather[81180:]
# Out:
#        index           Timestamp  air_temperature  water_temperature  \
# 81180  85325 2024-10-27 00:45:00             11.7               15.1
# 81181  85326 2024-10-27 00:50:00             11.6               15.1
# 81182  85327 2024-10-27 00:55:00             11.6               15.1
# 81183  85328 2024-10-27 01:00:00             11.6               15.1
# 81184  85329 2024-10-27 01:05:00             11.6               15.1
# ...      ...                 ...              ...                ...
# 85860  90005 2024-11-12 07:35:00              6.1               13.0
# 85861  90006 2024-11-12 07:40:00              6.1               13.0
# 85862  90007 2024-11-12 07:45:00              6.1               13.0
# 85863  90008 2024-11-12 07:50:00              6.1               13.0
# 85864  90009 2024-11-12 07:55:00              6.1               13.0
#
#        wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 81180                  2.9                   1.6                   1.6
# 81181                  1.7                   0.9                   0.9
# 81182                  1.7                   0.9                   0.9
# 81183                  2.8                   1.3                   1.3
# 81184                  2.8                   1.3                   1.3
# ...                    ...                   ...                   ...
# 85860                  4.8                   3.2                   3.2
# 85861                  5.1                   3.4                   3.4
# 85862                  5.1                   3.4                   3.4
# 85863                  5.8                   3.8                   3.8
# 85864                  5.8                   3.8                   3.8
#
#        wind_direction  windchill  barometric_pressure_qfe  precipitation  \
# 81180             142       11.5                    971.0            0.0
# 81181              61       11.6                    971.0            0.0
# 81182              61       11.6                    971.0            0.0
# 81183             149       11.6                    971.2            0.0
# 81184             149       11.6                    971.2            0.0
# ...               ...        ...                      ...            ...
# 85860              39        2.6                    977.7            0.0
# 85861              37        2.6                    977.8            0.0
# 85862              37        2.6                    977.8            0.0
# 85863              45        2.3                    977.8            0.0
# 85864              45        2.3                    977.8            0.0
#
#        dew_point  global_radiation  humidity  water_level  Feiertag
# 81180       10.6               0.0      93.0       405.97         1
# 81181       10.6               0.0      94.0       405.97         1
# 81182       10.6               0.0      94.0       405.97         1
# 81183       10.6               0.0      94.0       405.97         1
# 81184       10.6               0.0      94.0       405.97         1
# ...          ...               ...       ...          ...       ...
# 85860        4.9              13.0      92.0       405.87         0
# 85861        5.0              20.0      92.0       405.86         0
# 85862        5.0              20.0      92.0       405.86         0
# 85863        5.0              29.0      92.0       405.87         0
# 85864        5.0              29.0      92.0       405.87         0
#
# [4685 rows x 16 columns]

# %%
#Drop observations which dont match hardbruecke from weather
five_weather.drop(columns = ["index"], inplace = True)

# %% [markdown]
# ### Missing values for weather data

# %%
# Generate a full range of timestamps from the first to the last timestamp, at 5-minute intervals
full_range = pd.date_range(start=five_weather['Timestamp'].min(), end=five_weather['Timestamp'].max(), freq='5T')

# Find the missing timestamps by comparing with the existing ones
missing_timestamps = full_range[~full_range.isin(five_weather['Timestamp'])]

# Print the missing timestamps

missing_timestamps = pd.DataFrame(missing_timestamps)
missing_timestamps.rename(columns = {0: 'Timestamp'}, inplace = True)
missing_timestamps
missing_timestamps

# Duplicate rows
healed_weather = pd.concat([five_weather, missing_timestamps], ignore_index=True)


# Sort by timestamp to maintain order
healed_weather = healed_weather.sort_values(by='Timestamp').reset_index(drop=True)

#Interpolate missing values
weather_features = healed_weather.columns
weather_features = weather_features[1:14]

for i in weather_features:
    ff = healed_weather[i].ffill()
    bf = healed_weather[i].bfill()
    
    healed_weather[i] = healed_weather[i].fillna((ff + bf)/2)
    healed_weather
# Out:
# C:\Users\micha\AppData\Local\Temp\ipykernel_28304\1387657178.py:2: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   full_range = pd.date_range(start=five_weather['Timestamp'].min(), end=five_weather['Timestamp'].max(), freq='5T')

# %%
#Merge the two dataframes weather and hardbruecke
X = pd.merge(healed_weather, healed_VBZ, on = "Timestamp", how = "inner")
X
# Out:
#                 Timestamp  air_temperature  water_temperature  \
# 0     2024-01-16 14:55:00              4.0                5.4
# 1     2024-01-16 15:00:00              3.9                5.5
# 2     2024-01-16 15:05:00              3.9                5.5
# 3     2024-01-16 15:10:00              3.8                5.5
# 4     2024-01-16 15:15:00              3.8                5.5
# ...                   ...              ...                ...
# 86600 2024-11-12 07:35:00              6.1               13.0
# 86601 2024-11-12 07:40:00              6.1               13.0
# 86602 2024-11-12 07:45:00              6.1               13.0
# 86603 2024-11-12 07:50:00              6.1               13.0
# 86604 2024-11-12 07:55:00              6.1               13.0
#
#        wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 0                      4.1                   1.9                   1.9
# 1                      2.9                   1.6                   1.6
# 2                      2.9                   1.6                   1.6
# 3                      2.8                   0.9                   0.9
# 4                      2.8                   0.9                   0.9
# ...                    ...                   ...                   ...
# 86600                  4.8                   3.2                   3.2
# 86601                  5.1                   3.4                   3.4
# 86602                  5.1                   3.4                   3.4
# 86603                  5.8                   3.8                   3.8
# 86604                  5.8                   3.8                   3.8
#
#        wind_direction  windchill  barometric_pressure_qfe  precipitation  \
# 0                44.0        1.9                    962.5            0.0
# 1                 3.0        3.0                    962.5            0.0
# 2                 3.0        3.0                    962.5            0.0
# 3                55.0        3.5                    962.4            0.0
# 4                55.0        3.5                    962.4            0.0
# ...               ...        ...                      ...            ...
# 86600            39.0        2.6                    977.7            0.0
# 86601            37.0        2.6                    977.8            0.0
# 86602            37.0        2.6                    977.8            0.0
# 86603            45.0        2.3                    977.8            0.0
# 86604            45.0        2.3                    977.8            0.0
#
#        dew_point  global_radiation  humidity  water_level  Feiertag  \
# 0           -2.4             184.0      63.0       405.79       0.0
# 1           -2.5             137.0      63.0       405.79       0.0
# 2           -2.5             137.0      63.0       405.79       0.0
# 3           -2.6             169.0      63.0       405.79       0.0
# 4           -2.6             169.0      63.0       405.79       0.0
# ...          ...               ...       ...          ...       ...
# 86600        4.9              13.0      92.0       405.87       0.0
# 86601        5.0              20.0      92.0       405.86       0.0
# 86602        5.0              20.0      92.0       405.86       0.0
# 86603        5.0              29.0      92.0       405.87       0.0
# 86604        5.0              29.0      92.0       405.87       0.0
#
#        Ost-VBZ Total  West-VBZ total
# 0               13.0            20.0
# 1               14.0            11.0
# 2               29.0             6.0
# 3               18.0             9.0
# 4               33.0            16.0
# ...              ...             ...
# 86600          144.0            17.0
# 86601           91.0            25.0
# 86602           98.0            21.0
# 86603           68.0            27.0
# 86604           65.0            20.0
#
# [86605 rows x 17 columns]

# %%
X
# Out:
#                 Timestamp  air_temperature  water_temperature  \
# 0     2024-01-16 14:55:00              4.0                5.4
# 1     2024-01-16 15:00:00              3.9                5.5
# 2     2024-01-16 15:05:00              3.9                5.5
# 3     2024-01-16 15:10:00              3.8                5.5
# 4     2024-01-16 15:15:00              3.8                5.5
# ...                   ...              ...                ...
# 86600 2024-11-12 07:35:00              6.1               13.0
# 86601 2024-11-12 07:40:00              6.1               13.0
# 86602 2024-11-12 07:45:00              6.1               13.0
# 86603 2024-11-12 07:50:00              6.1               13.0
# 86604 2024-11-12 07:55:00              6.1               13.0
#
#        wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 0                      4.1                   1.9                   1.9
# 1                      2.9                   1.6                   1.6
# 2                      2.9                   1.6                   1.6
# 3                      2.8                   0.9                   0.9
# 4                      2.8                   0.9                   0.9
# ...                    ...                   ...                   ...
# 86600                  4.8                   3.2                   3.2
# 86601                  5.1                   3.4                   3.4
# 86602                  5.1                   3.4                   3.4
# 86603                  5.8                   3.8                   3.8
# 86604                  5.8                   3.8                   3.8
#
#        wind_direction  windchill  barometric_pressure_qfe  precipitation  \
# 0                44.0        1.9                    962.5            0.0
# 1                 3.0        3.0                    962.5            0.0
# 2                 3.0        3.0                    962.5            0.0
# 3                55.0        3.5                    962.4            0.0
# 4                55.0        3.5                    962.4            0.0
# ...               ...        ...                      ...            ...
# 86600            39.0        2.6                    977.7            0.0
# 86601            37.0        2.6                    977.8            0.0
# 86602            37.0        2.6                    977.8            0.0
# 86603            45.0        2.3                    977.8            0.0
# 86604            45.0        2.3                    977.8            0.0
#
#        dew_point  global_radiation  humidity  water_level  Feiertag  \
# 0           -2.4             184.0      63.0       405.79       0.0
# 1           -2.5             137.0      63.0       405.79       0.0
# 2           -2.5             137.0      63.0       405.79       0.0
# 3           -2.6             169.0      63.0       405.79       0.0
# 4           -2.6             169.0      63.0       405.79       0.0
# ...          ...               ...       ...          ...       ...
# 86600        4.9              13.0      92.0       405.87       0.0
# 86601        5.0              20.0      92.0       405.86       0.0
# 86602        5.0              20.0      92.0       405.86       0.0
# 86603        5.0              29.0      92.0       405.87       0.0
# 86604        5.0              29.0      92.0       405.87       0.0
#
#        Ost-VBZ Total  West-VBZ total
# 0               13.0            20.0
# 1               14.0            11.0
# 2               29.0             6.0
# 3               18.0             9.0
# 4               33.0            16.0
# ...              ...             ...
# 86600          144.0            17.0
# 86601           91.0            25.0
# 86602           98.0            21.0
# 86603           68.0            27.0
# 86604           65.0            20.0
#
# [86605 rows x 17 columns]

# %% [markdown]
# ### Add the t- variable

# %%
X.sort_values(by = "Timestamp",ascending=False, inplace = True)

#Add new variable for ost to shift values back
X["t-1 ost"] = X["Ost-VBZ Total"].shift(-1)
X["t-2 ost"] = X["Ost-VBZ Total"].shift(-2)
X["t-3 ost"] = X["Ost-VBZ Total"].shift(-3)
X["t-4 ost"] = X["Ost-VBZ Total"].shift(-4)
X["t-5 ost"] = X["Ost-VBZ Total"].shift(-5)

#Add new variable for west to shift values back
X["t-1 west"] = X["West-VBZ total"].shift(-1)
X["t-2 west"] = X["West-VBZ total"].shift(-2)
X["t-3 west"] = X["West-VBZ total"].shift(-3)
X["t-4 west"] = X["West-VBZ total"].shift(-4)
X["t-5 west"] = X["West-VBZ total"].shift(-5)

X.sort_values(by = "Timestamp",ascending=True, inplace = True)
X
# Out:
#                 Timestamp  air_temperature  water_temperature  \
# 0     2024-01-16 14:55:00              4.0                5.4
# 1     2024-01-16 15:00:00              3.9                5.5
# 2     2024-01-16 15:05:00              3.9                5.5
# 3     2024-01-16 15:10:00              3.8                5.5
# 4     2024-01-16 15:15:00              3.8                5.5
# ...                   ...              ...                ...
# 86600 2024-11-12 07:35:00              6.1               13.0
# 86601 2024-11-12 07:40:00              6.1               13.0
# 86602 2024-11-12 07:45:00              6.1               13.0
# 86603 2024-11-12 07:50:00              6.1               13.0
# 86604 2024-11-12 07:55:00              6.1               13.0
#
#        wind_gust_max_10min  wind_speed_avg_10min  wind_force_avg_10min  \
# 0                      4.1                   1.9                   1.9
# 1                      2.9                   1.6                   1.6
# 2                      2.9                   1.6                   1.6
# 3                      2.8                   0.9                   0.9
# 4                      2.8                   0.9                   0.9
# ...                    ...                   ...                   ...
# 86600                  4.8                   3.2                   3.2
# 86601                  5.1                   3.4                   3.4
# 86602                  5.1                   3.4                   3.4
# 86603                  5.8                   3.8                   3.8
# 86604                  5.8                   3.8                   3.8
#
#        wind_direction  windchill  barometric_pressure_qfe  precipitation  ...  \
# 0                44.0        1.9                    962.5            0.0  ...
# 1                 3.0        3.0                    962.5            0.0  ...
# 2                 3.0        3.0                    962.5            0.0  ...
# 3                55.0        3.5                    962.4            0.0  ...
# 4                55.0        3.5                    962.4            0.0  ...
# ...               ...        ...                      ...            ...  ...
# 86600            39.0        2.6                    977.7            0.0  ...
# 86601            37.0        2.6                    977.8            0.0  ...
# 86602            37.0        2.6                    977.8            0.0  ...
# 86603            45.0        2.3                    977.8            0.0  ...
# 86604            45.0        2.3                    977.8            0.0  ...
#
#        t-1 ost  t-2 ost  t-3 ost  t-4 ost  t-5 ost  t-1 west  t-2 west  \
# 0          NaN      NaN      NaN      NaN      NaN       NaN       NaN
# 1         13.0      NaN      NaN      NaN      NaN      20.0       NaN
# 2         14.0     13.0      NaN      NaN      NaN      11.0      20.0
# 3         29.0     14.0     13.0      NaN      NaN       6.0      11.0
# 4         18.0     29.0     14.0     13.0      NaN       9.0       6.0
# ...        ...      ...      ...      ...      ...       ...       ...
# 86600     40.0     66.0     75.0     75.0     96.0      51.0      32.0
# 86601    144.0     40.0     66.0     75.0     75.0      17.0      51.0
# 86602     91.0    144.0     40.0     66.0     75.0      25.0      17.0
# 86603     98.0     91.0    144.0     40.0     66.0      21.0      25.0
# 86604     68.0     98.0     91.0    144.0     40.0      27.0      21.0
#
#        t-3 west  t-4 west  t-5 west
# 0           NaN       NaN       NaN
# 1           NaN       NaN       NaN
# 2           NaN       NaN       NaN
# 3          20.0       NaN       NaN
# 4          11.0      20.0       NaN
# ...         ...       ...       ...
# 86600      19.0      31.0       9.0
# 86601      32.0      19.0      31.0
# 86602      51.0      32.0      19.0
# 86603      17.0      51.0      32.0
# 86604      25.0      17.0      51.0
#
# [86605 rows x 27 columns]
